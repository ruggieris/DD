# %%
# required modules (skip if already installed)
if False:
    # !pip install pyroaring
    # !pip install pyfim 
    # if previous does not work, try: !conda install -c conda-forge pyfim
    # !pip install lightgbm
    # !pip install fairlearn

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# global imports
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# local imports
sys.path.append('../src/') # local path
import dd

# %%
# read folkstable data
census = pd.read_pickle('../data/ACSIncome.pkl') 
states = list(census['STATE'].unique())
# change to True to binarize RAC1P
if False: 
    census["RAC1P"][census["RAC1P"]!='White alone'] = 'Not White alone'

# %%
# predictive attributes (for models)
pred_atts = ['AGEP', 'COW', 'SCHL', 'MAR', 'OCCP', 'POBP', 'WKHP', 'SEX', 'RAC1P', 'STATE']
pred_all = pred_atts + ['class']
# discretized attributes (for DD)
disc_atts = ['AGEPgroup', 'COW', 'SCHL', 'MAR', 'OCCPgroup', 'POBPgroup', 'WKHPgroup', 'SEX', 'RAC1P', 'STATE']
disc_all = disc_atts + ['class']
# encode categorical values
df, encoders = dd.encode(census)
df.head()
# Out:
#    AGEP  COW  SCHL  MAR   OCCP  POBP  WKHP  SEX RAC1P STATE class WKHPgroup  \
# 0   1.0  0.0  23.0  2.0  296.0  10.0  20.0  0.0   4.0   1.0   0.0       1.0
# 1  36.0  2.0   5.0  2.0  225.0  14.0  39.0  1.0   8.0   1.0   0.0       3.0
# 2  24.0  0.0  22.0  2.0  421.0   0.0  39.0  1.0   8.0   1.0   0.0       3.0
# 3   1.0  5.0  23.0  2.0  161.0   0.0   1.0  0.0   8.0   1.0   0.0       0.0
# 4   4.0  2.0   0.0  2.0  246.0   9.0  49.0  1.0   8.0   1.0   0.0       4.0
#
#   AGEPgroup POBPgroup OCCPgroup
# 0       0.0       5.0      22.0
# 1       3.0       5.0      12.0
# 2       1.0       5.0      21.0
# 3       0.0       5.0       8.0
# 4       0.0       5.0      20.0

# %%
# 0 = negative, 1 = positive
encoders['class'].classes_
# Out:
# array([False,  True])

# %%
# pretty printing long labels
pretty_rac1p = ['Alaska', 'Indian', 'Alaska-Indian', 'Asian', 'Black', 'Hawaiian', 'Other', 'Two+', 'White']
rac1p_2_pretty = { encoders['RAC1P'].classes_[i]:pretty_rac1p[i] for i in range(len(pretty_rac1p)) }
rac1p_2_pretty
# Out:
# {'Alaska Native alone': 'Alaska',
#  'American Indian alone': 'Indian',
#  'American Indian and Alaska Native tribes specified;or American Indian or Alaska Native,not specified and no other': 'Alaska-Indian',
#  'Asian alone': 'Asian',
#  'Black or African American alone': 'Black',
#  'Native Hawaiian and Other Pacific Islander alone': 'Hawaiian',
#  'Some Other Race alone': 'Other',
#  'Two or More Races': 'Two+',
#  'White alone': 'White'}

# %%
# split train test
X = df[pred_atts]
y = df['class'].astype(int)
X_train, X_test, y_train, y_test, census_train, census_test = train_test_split(X, y, census, test_size=0.33, random_state=42)

# %%
# training model and make predictions - replace with your favorite classifier
import lightgbm as lgb

clf = lgb.LGBMClassifier(random_state=42)
clf.fit(X_train, y_train)
# add predicted class in the census dataset (decoding back)
y_pred = clf.predict(X_test)
census_test['pred'] = encoders['class'].inverse_transform(y_pred)
# add predicted score in the adult_test
census_test['score'] = clf.predict_proba(X_test)[:,1]
census_test.head()
# Out:
#        AGEP                                                COW  \
# 517717   28  Employee of a private for-profit company orbus...
# 319156   56                        Federal government employee
# 507501   23  Employee of a private for-profit company orbus...
# 537835   33  Employee of a private for-profit company orbus...
# 305930   38  Employee of a private for-profit company orbus...
#
#                                       SCHL  \
# 517717  Some college, but less than 1 year
# 319156  Some college, but less than 1 year
# 507501                   Bachelor's degree
# 537835                   Bachelor's degree
# 305930                    Doctorate degree
#
#                                         MAR    OCCP POBP  WKHP     SEX  \
# 517717  Never married or under 15 years old  4700.0   37  50.0  Female
# 319156                             Divorced  4230.0   36  40.0    Male
# 507501  Never married or under 15 years old  1430.0   36  40.0    Male
# 537835                              Married  4710.0   17  50.0  Female
# 305930                              Married  3250.0   34  40.0  Female
#
#                                   RAC1P STATE  class WKHPgroup AGEPgroup  \
# 517717                      White alone    IL  False       >40     16-30
# 319156  Black or African American alone    CT  False     31-40     51-60
# 507501                      White alone    IL   True     31-40     16-30
# 537835                      White alone    IL   True       >40     31-40
# 305930                      White alone    CT   True     31-40     31-40
#
#        POBPgroup OCCPgroup   pred     score
# 517717        US       SAL  False  0.246374
# 319156        US       CLN  False  0.270322
# 507501        US       ENG  False  0.422198
# 537835        US       SAL   True  0.833683
# 305930        US       MED   True  0.917323

# %% [markdown]
# ### Performance metrics: misclassification error

# %%
# DD(filename or dataframe, unprotectedItem, predBadItem)
disc = dd.DD(census_test[disc_all+['pred']], unprotectedItem='class=True', predBadItem='pred=False')    
# confusion matrix
ctg = disc.ctg_any()
disc.print(ctg)
print("ERR = {:f}".format(ctg.err()))
# Out:
# -----
# Context ALL
# Size = 549285  Perc = 100.00%
#            |pred=False|pred=True|
# class!=True|    302169|    44777|346946
# class=True |     53463|   148876|202339
#            |    355632|   193653|549285
# ERR = 0.178851

# %% [markdown]
# ### Performance metrics: discovering errors in predictions

# %%
# filtering condition: return None to filter out, or measure value
# contingency table ctg such that ctg.n() >= minSupp 
'''
     confusion matrix (unprotected=true.good)
     =========== pred.bad === pred.good === 
     true.bad        a            b       n1()
     true.good       c            d       n2()
     ===========    m1()  ===    m2()  ==  n()
'''
def check_err(ctg):
    return ctg.err() if ctg.n()>0 else None # else None required in cover_n

# %%
ctgs_err = disc.extract(testCond=check_err, minSupp=-100, topk=1000)

# Top 3
for v, ctg in ctgs_err[:3]:
    disc.print(ctg)
    print("ERR = {:f}".format(check_err(ctg)))
# Out:
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 119  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        34|       25| 59
# class=True |        38|       22| 60
#            |        72|       47|119
# ERR = 0.529412
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=>40 AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 137  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        42|       29| 71
# class=True |        43|       23| 66
#            |        85|       52|137
# ERR = 0.525547
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND POBPgroup=US
# Size = 120  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        35|       25| 60
# class=True |        38|       22| 60
#            |        73|       47|120
# ERR = 0.525000

# %%
# sequential covering algorithm: 200 contingency tables
covers, residuals, times, uncovered, ctg_cov, ctg_uncov = \
    disc.cover_n([ctg for _,ctg in ctgs_err], check_err, 200, only_protected=False)

# %%
print('== Rejected ==')    
disc.print(ctg_cov)
print("ERR = {:f}".format(check_err(ctg_cov)))
print('== Selected ==')    
disc.print(ctg_uncov)
print("ERR = {:f}".format(check_err(ctg_uncov)))
print('\n== Cover CTs ==')    
for ctg, res in zip(covers, residuals):
    print(res)
    disc.print(ctg)
    print("ERR = {:f}".format(check_err(ctg)))
# Out:
# == Rejected ==
# -----
# Context <extensional>
# Size = 20245  Perc = 3.69%
#            |pred=False|pred=True|
# class!=True|      5775|     4512|10287
# class=True |      4502|     5456| 9958
#            |     10277|     9968|20245
# ERR = 0.445246
# == Selected ==
# -----
# Context <extensional>
# Size = 529040  Perc = 96.31%
#            |pred=False|pred=True|
# class!=True|    296394|    40265|336659
# class=True |     48961|   143420|192381
#            |    345355|   183685|529040
# ERR = 0.168656
#
# == Cover CTs ==
# 119
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 119  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        34|       25| 59
# class=True |        38|       22| 60
#            |        72|       47|119
# ERR = 0.529412
# 114
# -----
# Context OCCPgroup=EDU AND STATE=TX AND AGEPgroup=51-60 AND SCHL=Bachelor's degree AND WKHPgroup=31-40
# Size = 114  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        41|       13| 54
# class=True |        45|       15| 60
#            |        86|       28|114
# ERR = 0.508772
# 18
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=>40 AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 18  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         8|        4|12
# class=True |         5|        1| 6
#            |        13|        5|18
# ERR = 0.500000
# 101
# -----
# Context OCCPgroup=CMS AND COW=Employee of a private not-for-profit, tax-exempt,or charitable organization AND AGEPgroup=>60 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        11|       33| 44
# class=True |        17|       40| 57
#            |        28|       73|101
# ERR = 0.495050
# 113
# -----
# Context STATE=FL AND OCCPgroup=MGR AND AGEPgroup=31-40 AND SCHL=Bachelor's degree AND WKHPgroup=31-40
# Size = 113  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        16|       37| 53
# class=True |        18|       42| 60
#            |        34|       79|113
# ERR = 0.486726
# 107
# -----
# Context SCHL=GED or alternative credential AND COW=Self-employed in own incorporated business,professional practice or farm AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 107  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        19|       31| 50
# class=True |        21|       36| 57
#            |        40|       67|107
# ERR = 0.485981
# 103
# -----
# Context WKHPgroup=0-10 AND SCHL=Master's degree AND AGEPgroup=>60 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 103  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        24|       28| 52
# class=True |        22|       29| 51
#            |        46|       57|103
# ERR = 0.485437
# 101
# -----
# Context OCCPgroup=FIN AND SCHL=Regular high school diploma AND AGEPgroup=51-60 AND SEX=Female AND WKHPgroup=31-40
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        43|       20| 63
# class=True |        29|        9| 38
#            |        72|       29|101
# ERR = 0.485149
# 130
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married
# Size = 130  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        47|       23| 70
# class=True |        40|       20| 60
#            |        87|       43|130
# ERR = 0.484615
# 116
# -----
# Context STATE=NY AND OCCPgroup=TRN AND AGEPgroup=51-60 AND WKHPgroup=>40 AND POBPgroup=US
# Size = 116  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        18|       38| 56
# class=True |        18|       42| 60
#            |        36|       80|116
# ERR = 0.482759
# 106
# -----
# Context OCCPgroup=BUS AND SCHL=Regular high school diploma AND AGEPgroup=51-60 AND SEX=Female AND WKHPgroup=31-40 AND MAR=Married AND POBPgroup=US
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        45|       12| 57
# class=True |        39|       10| 49
#            |        84|       22|106
# ERR = 0.481132
# 104
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND SCHL=Master's degree AND AGEPgroup=31-40 AND WKHPgroup=31-40 AND RAC1P=White alone
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        12|       38| 50
# class=True |        12|       42| 54
#            |        24|       80|104
# ERR = 0.480769
# 129
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=SAL AND AGEPgroup=51-60 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 129  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        21|       39| 60
# class=True |        23|       46| 69
#            |        44|       85|129
# ERR = 0.480620
# 102
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=31-40 AND SEX=Male
# Size = 102  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|         7|       36| 43
# class=True |        13|       46| 59
#            |        20|       82|102
# ERR = 0.480392
# 100
# -----
# Context STATE=IL AND OCCPgroup=CON AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND POBPgroup=US
# Size = 100  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        30|       17| 47
# class=True |        31|       22| 53
#            |        61|       39|100
# ERR = 0.480000
# 113
# -----
# Context STATE=PA AND OCCPgroup=TRN AND AGEPgroup=41-50 AND WKHPgroup=>40 AND SEX=Male
# Size = 113  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       35| 57
# class=True |        19|       37| 56
#            |        41|       72|113
# ERR = 0.477876
# 128
# -----
# Context OCCPgroup=OFF AND STATE=CA AND AGEPgroup=>60 AND SEX=Female AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 128  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        37|       29| 66
# class=True |        32|       30| 62
#            |        69|       59|128
# ERR = 0.476562
# 105
# -----
# Context OCCPgroup=RPR AND MAR=Divorced AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male
# Size = 105  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        20|       34| 54
# class=True |        16|       35| 51
#            |        36|       69|105
# ERR = 0.476190
# 101
# -----
# Context MAR=Widowed AND WKHPgroup=11-20 AND SCHL=Master's degree
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        23|       14| 37
# class=True |        34|       30| 64
#            |        57|       44|101
# ERR = 0.475248
# 114
# -----
# Context OCCPgroup=EDU AND STATE=TX AND AGEPgroup=41-50 AND SCHL=Bachelor's degree AND WKHPgroup=31-40 AND RAC1P=White alone
# Size = 114  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        49|        8| 57
# class=True |        46|       11| 57
#            |        95|       19|114
# ERR = 0.473684
# 110
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=TRN AND AGEPgroup=>60 AND WKHPgroup=>40 AND POBPgroup=US
# Size = 110  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       23| 50
# class=True |        29|       31| 60
#            |        56|       54|110
# ERR = 0.472727
# 104
# -----
# Context OCCPgroup=CLN AND AGEPgroup=>60 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       30| 57
# class=True |        19|       28| 47
#            |        46|       58|104
# ERR = 0.471154
# 115
# -----
# Context STATE=TN AND OCCPgroup=FIN AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 115  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        32|       35| 67
# class=True |        19|       29| 48
#            |        51|       64|115
# ERR = 0.469565
# 111
# -----
# Context STATE=MN AND OCCPgroup=PRD AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 111  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        43|       21| 64
# class=True |        31|       16| 47
#            |        74|       37|111
# ERR = 0.468468
# 105
# -----
# Context OCCPgroup=EDU AND STATE=TX AND AGEPgroup=31-40 AND SCHL=Bachelor's degree AND WKHPgroup=>40 AND SEX=Female
# Size = 105  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        40|       14| 54
# class=True |        35|       16| 51
#            |        75|       30|105
# ERR = 0.466667
# 108
# -----
# Context SCHL=Associate's degree AND OCCPgroup=SAL AND AGEPgroup=41-50 AND WKHPgroup=>40 AND SEX=Female
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        33|       24| 57
# class=True |        26|       25| 51
#            |        59|       49|108
# ERR = 0.462963
# 121
# -----
# Context OCCPgroup=EDU AND SCHL=Master's degree AND MAR=Never married or under 15 years old AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 121  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        42|       30| 72
# class=True |        26|       23| 49
#            |        68|       53|121
# ERR = 0.462810
# 208
# -----
# Context STATE=NJ AND OCCPgroup=OFF AND AGEPgroup=51-60 AND SEX=Female AND WKHPgroup=31-40 AND RAC1P=White alone
# Size = 208  Perc = 0.04%
#            |pred=False|pred=True|
# class=False|        82|       33|115
# class=True |        63|       30| 93
#            |       145|       63|208
# ERR = 0.461538
# 91
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND AGEPgroup=41-50 AND WKHPgroup=>40 AND SEX=Male AND RAC1P=White alone
# Size = 91  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        34|       12|46
# class=True |        30|       15|45
#            |        64|       27|91
# ERR = 0.461538
# 5
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone
# Size = 5  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         0|        2|2
# class=True |         1|        2|3
#            |         1|        4|5
# ERR = 0.600000
# 102
# -----
# Context WKHPgroup=21-30 AND OCCPgroup=MGR AND AGEPgroup=>60 AND SCHL=Regular high school diploma AND MAR=Married
# Size = 102  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        46|        4| 50
# class=True |        43|        9| 52
#            |        89|       13|102
# ERR = 0.460784
# 89
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND SCHL=Associate's degree AND AGEPgroup=>60 AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 89  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       26|48
# class=True |        15|       26|41
#            |        37|       52|89
# ERR = 0.460674
# 189
# -----
# Context SCHL=Grade 11 AND AGEPgroup=51-60 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married
# Size = 189  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        58|       30| 88
# class=True |        57|       44|101
#            |       115|       74|189
# ERR = 0.460317
# 124
# -----
# Context STATE=LA AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 124  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        33|       26| 59
# class=True |        31|       34| 65
#            |        64|       60|124
# ERR = 0.459677
# 85
# -----
# Context WKHPgroup=0-10 AND OCCPgroup=EDU AND SCHL=Master's degree AND AGEPgroup=>60 AND SEX=Male AND RAC1P=White alone
# Size = 85  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        18|       25|43
# class=True |        14|       28|42
#            |        32|       53|85
# ERR = 0.458824
# 100
# -----
# Context WKHPgroup=0-10 AND SCHL=Master's degree AND STATE=CA AND AGEPgroup=>60 AND RAC1P=White alone AND POBPgroup=US
# Size = 100  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        28|       15| 43
# class=True |        32|       25| 57
#            |        60|       40|100
# ERR = 0.470000
# 205
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND AGEPgroup=41-50 AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 205  Perc = 0.04%
#            |pred=False|pred=True|
# class=False|        74|       37|111
# class=True |        57|       37| 94
#            |       131|       74|205
# ERR = 0.458537
# 144
# -----
# Context WKHPgroup=0-10 AND AGEPgroup=>60 AND SCHL=Bachelor's degree AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 144  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        57|       29| 86
# class=True |        37|       21| 58
#            |        94|       50|144
# ERR = 0.458333
# 129
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=MGR AND SCHL=Regular high school diploma AND AGEPgroup=51-60 AND WKHPgroup=>40 AND MAR=Married AND RAC1P=White alone
# Size = 129  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        49|       16| 65
# class=True |        43|       21| 64
#            |        92|       37|129
# ERR = 0.457364
# 105
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND AGEPgroup=31-40 AND SCHL=Bachelor's degree AND SEX=Female AND WKHPgroup=31-40 AND RAC1P=White alone
# Size = 105  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        35|       24| 59
# class=True |        24|       22| 46
#            |        59|       46|105
# ERR = 0.457143
# 105
# -----
# Context STATE=TX AND SCHL=Associate's degree AND AGEPgroup=41-50 AND WKHPgroup=31-40 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 105  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        18|       21| 39
# class=True |        27|       39| 66
#            |        45|       60|105
# ERR = 0.457143
# 116
# -----
# Context OCCPgroup=CON AND COW=Self-employed in own not incorporated business,professional practice, or farm AND STATE=CA AND WKHPgroup=31-40 AND RAC1P=White alone AND POBPgroup=US
# Size = 116  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        41|       18| 59
# class=True |        35|       22| 57
#            |        76|       40|116
# ERR = 0.456897
# 125
# -----
# Context OCCPgroup=CMS AND COW=Employee of a private not-for-profit, tax-exempt,or charitable organization AND SCHL=Master's degree AND AGEPgroup=41-50 AND WKHPgroup=31-40
# Size = 125  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       45| 67
# class=True |        12|       46| 58
#            |        34|       91|125
# ERR = 0.456000
# 79
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=TRN AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40
# Size = 79  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        38|        5|43
# class=True |        31|        5|36
#            |        69|       10|79
# ERR = 0.455696
# 124
# -----
# Context OCCPgroup=TRN AND MAR=Divorced AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40 AND SEX=Male AND RAC1P=White alone AND POBPgroup=US
# Size = 124  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        28|       35| 63
# class=True |        22|       39| 61
#            |        50|       74|124
# ERR = 0.459677
# 101
# -----
# Context SCHL=Associate's degree AND OCCPgroup=SAL AND AGEPgroup=41-50 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        24|       31| 55
# class=True |        15|       31| 46
#            |        39|       62|101
# ERR = 0.455446
# 22
# -----
# Context OCCPgroup=OFF AND STATE=CA AND AGEPgroup=>60 AND SEX=Female AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 22  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         7|        1| 8
# class=True |         9|        5|14
#            |        16|        6|22
# ERR = 0.454545
# 11
# -----
# Context WKHPgroup=0-10 AND AGEPgroup=>60 AND SCHL=Bachelor's degree AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 11  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         6|        1| 7
# class=True |         4|        0| 4
#            |        10|        1|11
# ERR = 0.454545
# 11
# -----
# Context WKHPgroup=0-10 AND SCHL=Master's degree AND STATE=CA AND AGEPgroup=>60
# Size = 11  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         4|        2| 6
# class=True |         3|        2| 5
#            |         7|        4|11
# ERR = 0.454545
# 141
# -----
# Context OCCPgroup=ENT AND COW=Self-employed in own not incorporated business,professional practice, or farm AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND POBPgroup=US
# Size = 141  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        51|       31| 82
# class=True |        33|       26| 59
#            |        84|       57|141
# ERR = 0.453901
# 108
# -----
# Context RAC1P=Some Other Race alone AND STATE=CA AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        47|       18| 65
# class=True |        31|       12| 43
#            |        78|       30|108
# ERR = 0.453704
# 97
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=CON AND AGEPgroup=>60 AND WKHPgroup=31-40 AND SEX=Male AND RAC1P=White alone AND POBPgroup=US
# Size = 97  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        25|       25|50
# class=True |        19|       28|47
#            |        44|       53|97
# ERR = 0.453608
# 128
# -----
# Context OCCPgroup=EDU AND WKHPgroup=21-30 AND AGEPgroup=>60 AND SEX=Male AND MAR=Married AND POBPgroup=US
# Size = 128  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        20|       38| 58
# class=True |        20|       50| 70
#            |        40|       88|128
# ERR = 0.453125
# 129
# -----
# Context OCCPgroup=EDU AND SCHL=Master's degree AND AGEPgroup=>60 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 129  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        28|       42| 70
# class=True |        17|       42| 59
#            |        45|       84|129
# ERR = 0.457364
# 106
# -----
# Context OCCPgroup=RPR AND SCHL=Associate's degree AND AGEPgroup=31-40 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        29|       15| 44
# class=True |        33|       29| 62
#            |        62|       44|106
# ERR = 0.452830
# 106
# -----
# Context OCCPgroup=BUS AND COW=Self-employed in own incorporated business,professional practice or farm AND WKHPgroup=21-30 AND RAC1P=White alone
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        17|       33| 50
# class=True |        15|       41| 56
#            |        32|       74|106
# ERR = 0.452830
# 84
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND SCHL=Associate's degree AND OCCPgroup=MGR AND AGEPgroup=51-60 AND MAR=Married
# Size = 84  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        10|       26|36
# class=True |        12|       36|48
#            |        22|       62|84
# ERR = 0.452381
# 97
# -----
# Context STATE=AZ AND COW=Self-employed in own incorporated business,professional practice or farm AND SEX=Female AND MAR=Married AND POBPgroup=US
# Size = 97  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        32|       13|45
# class=True |        31|       21|52
#            |        63|       34|97
# ERR = 0.453608
# 199
# -----
# Context OCCPgroup=RPR AND COW=Self-employed in own incorporated business,professional practice or farm AND WKHPgroup=>40 AND POBPgroup=US
# Size = 199  Perc = 0.04%
#            |pred=False|pred=True|
# class=False|        26|       71| 97
# class=True |        19|       83|102
#            |        45|      154|199
# ERR = 0.452261
# 104
# -----
# Context OCCPgroup=CON AND COW=Self-employed in own not incorporated business,professional practice, or farm AND AGEPgroup=>60 AND WKHPgroup=>40 AND SEX=Male AND RAC1P=White alone
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        38|       22| 60
# class=True |        25|       19| 44
#            |        63|       41|104
# ERR = 0.451923
# 93
# -----
# Context OCCPgroup=FIN AND COW=State government employee AND AGEPgroup=51-60 AND SEX=Female
# Size = 93  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       31|53
# class=True |        11|       29|40
#            |        33|       60|93
# ERR = 0.451613
# 124
# -----
# Context OCCPgroup=CLN AND AGEPgroup=41-50 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 124  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        35|       28| 63
# class=True |        28|       33| 61
#            |        63|       61|124
# ERR = 0.451613
# 102
# -----
# Context OCCPgroup=CLN AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 102  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        32|       14| 46
# class=True |        33|       23| 56
#            |        65|       37|102
# ERR = 0.460784
# 113
# -----
# Context STATE=MN AND OCCPgroup=TRN AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND RAC1P=White alone AND POBPgroup=US
# Size = 113  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        26|       32| 58
# class=True |        19|       36| 55
#            |        45|       68|113
# ERR = 0.451327
# 111
# -----
# Context STATE=TX AND MAR=Divorced AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40 AND SEX=Male
# Size = 111  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        17|       38| 55
# class=True |        12|       44| 56
#            |        29|       82|111
# ERR = 0.450450
# 131
# -----
# Context SCHL=Associate's degree AND OCCPgroup=MGR AND AGEPgroup=51-60 AND SEX=Female AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 131  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       28| 55
# class=True |        31|       45| 76
#            |        58|       73|131
# ERR = 0.450382
# 109
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND WKHPgroup=21-30 AND OCCPgroup=SAL AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 109  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        19|       21| 40
# class=True |        28|       41| 69
#            |        47|       62|109
# ERR = 0.449541
# 109
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=SAL AND AGEPgroup=51-60 AND SCHL=Bachelor's degree AND SEX=Female
# Size = 109  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       34| 56
# class=True |        15|       38| 53
#            |        37|       72|109
# ERR = 0.449541
# 98
# -----
# Context SCHL=Some college, but less than 1 year AND OCCPgroup=TRN AND STATE=CA AND WKHPgroup=>40
# Size = 98  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        30|       24|54
# class=True |        20|       24|44
#            |        50|       48|98
# ERR = 0.448980
# 107
# -----
# Context OCCPgroup=RPR AND STATE=PA AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND MAR=Married AND RAC1P=White alone
# Size = 107  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        33|       12| 45
# class=True |        36|       26| 62
#            |        69|       38|107
# ERR = 0.448598
# 65
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=TRN AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 65  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        14|       12|26
# class=True |        17|       22|39
#            |        31|       34|65
# ERR = 0.446154
# 92
# -----
# Context STATE=IL AND AGEPgroup=>60 AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married
# Size = 92  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       18|45
# class=True |        23|       24|47
#            |        50|       42|92
# ERR = 0.445652
# 22
# -----
# Context STATE=IL AND AGEPgroup=>60 AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND SEX=Male AND POBPgroup=US
# Size = 22  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|        10|        2|12
# class=True |         8|        2|10
#            |        18|        4|22
# ERR = 0.454545
# 101
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=SAL AND STATE=CA AND SEX=Female AND WKHPgroup=31-40
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        33|       27| 60
# class=True |        18|       23| 41
#            |        51|       50|101
# ERR = 0.445545
# 110
# -----
# Context OCCPgroup=OFF AND AGEPgroup=51-60 AND SCHL=Bachelor's degree AND WKHPgroup=>40 AND SEX=Female AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 110  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        10|       37| 47
# class=True |        12|       51| 63
#            |        22|       88|110
# ERR = 0.445455
# 119
# -----
# Context OCCPgroup=PRD AND SCHL=Some college, but less than 1 year AND AGEPgroup=51-60 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 119  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       23| 50
# class=True |        30|       39| 69
#            |        57|       62|119
# ERR = 0.445378
# 128
# -----
# Context OCCPgroup=ENT AND STATE=NY AND SCHL=Bachelor's degree AND SEX=Female AND WKHPgroup=31-40
# Size = 128  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        25|       26| 51
# class=True |        31|       46| 77
#            |        56|       72|128
# ERR = 0.445312
# 45
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=TRN AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND RAC1P=White alone AND POBPgroup=US
# Size = 45  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        22|        1|23
# class=True |        19|        3|22
#            |        41|        4|45
# ERR = 0.444444
# 108
# -----
# Context SCHL=Associate's degree AND OCCPgroup=OFF AND AGEPgroup=>60 AND WKHPgroup=31-40 AND SEX=Male
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        23|       20| 43
# class=True |        28|       37| 65
#            |        51|       57|108
# ERR = 0.444444
# 90
# -----
# Context OCCPgroup=CON AND SCHL=Some college, but less than 1 year AND AGEPgroup=>60 AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 90  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       22|44
# class=True |        18|       28|46
#            |        40|       50|90
# ERR = 0.444444
# 108
# -----
# Context STATE=NC AND COW=State government employee AND OCCPgroup=EDU AND SCHL=Master's degree AND SEX=Female AND POBPgroup=US
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        40|       22| 62
# class=True |        26|       20| 46
#            |        66|       42|108
# ERR = 0.444444
# 9
# -----
# Context OCCPgroup=CLN AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone
# Size = 9  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         5|        3|8
# class=True |         1|        0|1
#            |         6|        3|9
# ERR = 0.444444
# 45
# -----
# Context OCCPgroup=OFF AND AGEPgroup=51-60 AND SCHL=Bachelor's degree AND WKHPgroup=>40 AND SEX=Female AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 45  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|         9|       16|25
# class=True |         4|       16|20
#            |        13|       32|45
# ERR = 0.444444
# 81
# -----
# Context OCCPgroup=CON AND COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 81  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        38|        6|44
# class=True |        30|        7|37
#            |        68|       13|81
# ERR = 0.444444
# 115
# -----
# Context STATE=GA AND OCCPgroup=TRN AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 115  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        24|       31| 55
# class=True |        20|       40| 60
#            |        44|       71|115
# ERR = 0.443478
# 106
# -----
# Context OCCPgroup=FIN AND SCHL=Master's degree AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND WKHPgroup=31-40
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        20|       25| 45
# class=True |        22|       39| 61
#            |        42|       64|106
# ERR = 0.443396
# 79
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=SAL AND AGEPgroup=51-60 AND WKHPgroup=>40 AND SEX=Female AND RAC1P=White alone
# Size = 79  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        20|       24|44
# class=True |        11|       24|35
#            |        31|       48|79
# ERR = 0.443038
# 101
# -----
# Context STATE=MO AND SCHL=Regular high school diploma AND AGEPgroup=51-60 AND WKHPgroup=>40 AND MAR=Married AND POBPgroup=US
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        18|       34| 52
# class=True |        11|       38| 49
#            |        29|       72|101
# ERR = 0.445545
# 90
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=SAL AND WKHPgroup=>40 AND MAR=Never married or under 15 years old AND RAC1P=White alone AND POBPgroup=US
# Size = 90  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        20|       21|41
# class=True |        19|       30|49
#            |        39|       51|90
# ERR = 0.444444
# 122
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=MGR AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=31-40 AND MAR=Married AND RAC1P=White alone
# Size = 122  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        38|       28| 66
# class=True |        26|       30| 56
#            |        64|       58|122
# ERR = 0.442623
# 104
# -----
# Context STATE=TX AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40 AND AGEPgroup=16-30 AND SEX=Male AND MAR=Married AND RAC1P=White alone
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        39|       19| 58
# class=True |        27|       19| 46
#            |        66|       38|104
# ERR = 0.442308
# 104
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=MGR AND AGEPgroup=>60 AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       29| 56
# class=True |        17|       31| 48
#            |        44|       60|104
# ERR = 0.442308
# 79
# -----
# Context STATE=IN AND COW=Self-employed in own not incorporated business,professional practice, or farm AND WKHPgroup=>40 AND SEX=Male AND RAC1P=White alone AND POBPgroup=US
# Size = 79  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        28|       12|40
# class=True |        23|       16|39
#            |        51|       28|79
# ERR = 0.443038
# 111
# -----
# Context RAC1P=Black or African American alone AND AGEPgroup=41-50 AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 111  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        39|       29| 68
# class=True |        20|       23| 43
#            |        59|       52|111
# ERR = 0.441441
# 135
# -----
# Context STATE=OH AND OCCPgroup=PRD AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 135  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        28|       34| 62
# class=True |        26|       47| 73
#            |        54|       81|135
# ERR = 0.444444
# 111
# -----
# Context OCCPgroup=BUS AND SCHL=Associate's degree AND AGEPgroup=31-40 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 111  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        28|       34| 62
# class=True |        15|       34| 49
#            |        43|       68|111
# ERR = 0.441441
# 102
# -----
# Context OCCPgroup=CMS AND COW=Employee of a private not-for-profit, tax-exempt,or charitable organization AND SCHL=Master's degree AND AGEPgroup=51-60 AND WKHPgroup=31-40 AND RAC1P=White alone AND POBPgroup=US
# Size = 102  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        16|       36| 52
# class=True |         9|       41| 50
#            |        25|       77|102
# ERR = 0.441176
# 102
# -----
# Context OCCPgroup=EXT AND WKHPgroup=>40 AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 102  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        30|       19| 49
# class=True |        26|       27| 53
#            |        56|       46|102
# ERR = 0.441176
# 127
# -----
# Context STATE=PA AND OCCPgroup=CON AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US AND RAC1P=White alone
# Size = 127  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        42|       20| 62
# class=True |        36|       29| 65
#            |        78|       49|127
# ERR = 0.440945
# 152
# -----
# Context STATE=CT AND OCCPgroup=OFF AND WKHPgroup=31-40 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 152  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        56|       27| 83
# class=True |        40|       29| 69
#            |        96|       56|152
# ERR = 0.440789
# 118
# -----
# Context OCCPgroup=BUS AND AGEPgroup=31-40 AND SCHL=Bachelor's degree AND MAR=Never married or under 15 years old AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 118  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        13|       38| 51
# class=True |        14|       53| 67
#            |        27|       91|118
# ERR = 0.440678
# 116
# -----
# Context OCCPgroup=CON AND AGEPgroup=>60 AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=31-40 AND MAR=Married AND POBPgroup=US
# Size = 116  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        21|       37| 58
# class=True |        14|       44| 58
#            |        35|       81|116
# ERR = 0.439655
# 89
# -----
# Context COW=Local government employee (city, county, etc.) AND WKHPgroup=21-30 AND SCHL=Master's degree AND AGEPgroup=>60 AND POBPgroup=US
# Size = 89  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        17|       25|42
# class=True |        14|       33|47
#            |        31|       58|89
# ERR = 0.438202
# 160
# -----
# Context OCCPgroup=RPR AND SCHL=Associate's degree AND WKHPgroup=>40 AND MAR=Never married or under 15 years old AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 160  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        66|       19| 85
# class=True |        51|       24| 75
#            |       117|       43|160
# ERR = 0.437500
# 2
# -----
# Context OCCPgroup=RPR AND SCHL=Associate's degree AND WKHPgroup=>40 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 2  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         1|        0|1
# class=True |         1|        0|1
#            |         2|        0|2
# ERR = 0.500000
# 96
# -----
# Context MAR=Widowed AND OCCPgroup=ENT AND AGEPgroup=>60 AND SEX=Female
# Size = 96  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        37|       15|52
# class=True |        27|       17|44
#            |        64|       32|96
# ERR = 0.437500
# 87
# -----
# Context WKHPgroup=0-10 AND OCCPgroup=MGR AND SCHL=Bachelor's degree AND SEX=Male AND MAR=Married
# Size = 87  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        23|       21|44
# class=True |        17|       26|43
#            |        40|       47|87
# ERR = 0.436782
# 110
# -----
# Context STATE=GA AND OCCPgroup=MED AND SCHL=Associate's degree AND SEX=Female AND MAR=Married AND POBPgroup=US
# Size = 110  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        31|       28| 59
# class=True |        20|       31| 51
#            |        51|       59|110
# ERR = 0.436364
# 94
# -----
# Context OCCPgroup=TRN AND STATE=CA AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male AND RAC1P=White alone
# Size = 94  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        28|       15|43
# class=True |        26|       25|51
#            |        54|       40|94
# ERR = 0.436170
# 100
# -----
# Context SCHL=Associate's degree AND MAR=Divorced AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 100  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        10|       29| 39
# class=True |        15|       46| 61
#            |        25|       75|100
# ERR = 0.440000
# 117
# -----
# Context SCHL=GED or alternative credential AND COW=Self-employed in own not incorporated business,professional practice, or farm AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 117  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        47|       15| 62
# class=True |        36|       19| 55
#            |        83|       34|117
# ERR = 0.435897
# 101
# -----
# Context STATE=TN AND SCHL=Regular high school diploma AND AGEPgroup=51-60 AND WKHPgroup=>40 AND MAR=Married AND POBPgroup=US
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        25|       27| 52
# class=True |        17|       32| 49
#            |        42|       59|101
# ERR = 0.435644
# 108
# -----
# Context OCCPgroup=RPR AND AGEPgroup=31-40 AND SCHL=Bachelor's degree AND WKHPgroup=31-40 AND RAC1P=White alone
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        24|       31| 55
# class=True |        16|       37| 53
#            |        40|       68|108
# ERR = 0.435185
# 145
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=SAL AND AGEPgroup=51-60 AND WKHPgroup=31-40 AND SEX=Male AND RAC1P=White alone AND POBPgroup=US
# Size = 145  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        38|       44| 82
# class=True |        19|       44| 63
#            |        57|       88|145
# ERR = 0.434483
# 99
# -----
# Context STATE=IL AND OCCPgroup=CON AND AGEPgroup=41-50 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 99  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        24|       27|51
# class=True |        16|       32|48
#            |        40|       59|99
# ERR = 0.434343
# 99
# -----
# Context OCCPgroup=SAL AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Female AND RAC1P=White alone AND POBPgroup=US
# Size = 99  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        34|       19|53
# class=True |        24|       22|46
#            |        58|       41|99
# ERR = 0.434343
# 106
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=MGR AND MAR=Never married or under 15 years old AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        34|       26| 60
# class=True |        20|       26| 46
#            |        54|       52|106
# ERR = 0.433962
# 106
# -----
# Context SCHL=GED or alternative credential AND OCCPgroup=CON AND AGEPgroup=41-50 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        45|       15| 60
# class=True |        31|       15| 46
#            |        76|       30|106
# ERR = 0.433962
# 113
# -----
# Context STATE=NY AND COW=Local government employee (city, county, etc.) AND OCCPgroup=TRN AND WKHPgroup=31-40
# Size = 113  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        42|       11| 53
# class=True |        38|       22| 60
#            |        80|       33|113
# ERR = 0.433628
# 112
# -----
# Context COW=Local government employee (city, county, etc.) AND OCCPgroup=TRN AND AGEPgroup=>60 AND WKHPgroup=31-40 AND SEX=Male
# Size = 112  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        47|       15| 62
# class=True |        34|       16| 50
#            |        81|       31|112
# ERR = 0.437500
# 120
# -----
# Context OCCPgroup=RPR AND SCHL=Associate's degree AND MAR=Divorced AND WKHPgroup=31-40 AND SEX=Male AND RAC1P=White alone AND POBPgroup=US
# Size = 120  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        33|       23| 56
# class=True |        29|       35| 64
#            |        62|       58|120
# ERR = 0.433333
# 116
# -----
# Context OCCPgroup=RPR AND COW=Federal government employee AND AGEPgroup=31-40
# Size = 116  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        26|       41| 67
# class=True |        10|       39| 49
#            |        36|       80|116
# ERR = 0.439655
# 201
# -----
# Context OCCPgroup=RPR AND AGEPgroup=41-50 AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 201  Perc = 0.04%
#            |pred=False|pred=True|
# class=False|        60|       34| 94
# class=True |        53|       54|107
#            |       113|       88|201
# ERR = 0.432836
# 134
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND WKHPgroup=21-30 AND OCCPgroup=SAL AND SEX=Male AND MAR=Married AND RAC1P=White alone
# Size = 134  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        45|       19| 64
# class=True |        39|       31| 70
#            |        84|       50|134
# ERR = 0.432836
# 104
# -----
# Context OCCPgroup=MGR AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND AGEPgroup=16-30 AND SEX=Male AND MAR=Married
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        37|       19| 56
# class=True |        26|       22| 48
#            |        63|       41|104
# ERR = 0.432692
# 104
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=MGR AND MAR=Divorced AND WKHPgroup=31-40 AND SEX=Male
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        41|       21| 62
# class=True |        24|       18| 42
#            |        65|       39|104
# ERR = 0.432692
# 111
# -----
# Context STATE=NY AND OCCPgroup=EDU AND SCHL=Master's degree AND AGEPgroup=16-30 AND SEX=Female AND RAC1P=White alone AND POBPgroup=US
# Size = 111  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        35|       22| 57
# class=True |        26|       28| 54
#            |        61|       50|111
# ERR = 0.432432
# 74
# -----
# Context OCCPgroup=BUS AND AGEPgroup=31-40 AND SCHL=Bachelor's degree AND MAR=Never married or under 15 years old AND SEX=Female AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 74  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|         9|       24|33
# class=True |         8|       33|41
#            |        17|       57|74
# ERR = 0.432432
# 81
# -----
# Context OCCPgroup=ENT AND COW=Self-employed in own not incorporated business,professional practice, or farm AND SCHL=Master's degree AND WKHPgroup=31-40
# Size = 81  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        25|       28|53
# class=True |         7|       21|28
#            |        32|       49|81
# ERR = 0.432099
# 125
# -----
# ...
# 98
# -----
# Context STATE=WI AND OCCPgroup=PRD AND AGEPgroup=51-60 AND WKHPgroup=>40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 98  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       19|41
# class=True |        23|       34|57
#            |        45|       53|98
# ERR = 0.428571
# 110
# -----
# Context OCCPgroup=CLN AND SCHL=Regular high school diploma AND AGEPgroup=51-60 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married
# Size = 110  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        41|       23| 64
# class=True |        24|       22| 46
#            |        65|       45|110
# ERR = 0.427273
# 76
# -----
# Context OCCPgroup=CLN AND COW=Self-employed in own incorporated business,professional practice or farm AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone
# Size = 76  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        24|       18|42
# class=True |        17|       17|34
#            |        41|       35|76
# ERR = 0.460526
# 11
# -----
# Context OCCPgroup=CLN AND COW=Self-employed in own incorporated business,professional practice or farm AND WKHPgroup=>40 AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 11  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         6|        1| 7
# class=True |         4|        0| 4
#            |        10|        1|11
# ERR = 0.454545
# 110
# -----
# Context OCCPgroup=MED AND COW=Local government employee (city, county, etc.) AND SCHL=Associate's degree AND WKHPgroup=31-40 AND MAR=Married
# Size = 110  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        27|       34| 61
# class=True |        13|       36| 49
#            |        40|       70|110
# ERR = 0.427273
# 61
# -----
# Context OCCPgroup=EDU AND STATE=TX AND WKHPgroup=>40 AND AGEPgroup=16-30
# Size = 61  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        26|        6|32
# class=True |        20|        9|29
#            |        46|       15|61
# ERR = 0.426230
# 115
# -----
# Context POBPgroup=Asia AND OCCPgroup=OFF AND AGEPgroup=>60 AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 115  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        46|       19| 65
# class=True |        30|       20| 50
#            |        76|       39|115
# ERR = 0.426087
# 115
# -----
# Context OCCPgroup=EAT AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 115  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        44|       25| 69
# class=True |        24|       22| 46
#            |        68|       47|115
# ERR = 0.426087
# 108
# -----
# Context STATE=PA AND MAR=Divorced AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND RAC1P=White alone
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        22|       23| 45
# class=True |        23|       40| 63
#            |        45|       63|108
# ERR = 0.425926
# 118
# -----
# Context OCCPgroup=RPR AND MAR=Divorced AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 118  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        18|       35| 53
# class=True |        17|       48| 65
#            |        35|       83|118
# ERR = 0.440678
# 7
# -----
# Context STATE=PA AND MAR=Divorced AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 7  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         2|        1|3
# class=True |         2|        2|4
#            |         4|        3|7
# ERR = 0.428571
# 108
# -----
# Context OCCPgroup=OFF AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=51-60 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 108  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        39|       17| 56
# class=True |        29|       23| 52
#            |        68|       40|108
# ERR = 0.425926
# 101
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=TRN AND AGEPgroup=41-50 AND MAR=Married AND RAC1P=White alone
# Size = 101  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        38|       23| 61
# class=True |        20|       20| 40
#            |        58|       43|101
# ERR = 0.425743
# 94
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=MGR AND MAR=Divorced AND WKHPgroup=31-40 AND SEX=Male
# Size = 94  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        10|       32|42
# class=True |         8|       44|52
#            |        18|       76|94
# ERR = 0.425532
# 47
# -----
# Context STATE=CT AND OCCPgroup=OFF AND SEX=Female AND WKHPgroup=31-40 AND MAR=Married AND RAC1P=White alone
# Size = 47  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        15|        6|21
# class=True |        14|       12|26
#            |        29|       18|47
# ERR = 0.425532
# 127
# -----
# Context OCCPgroup=RPR AND STATE=IL AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 127  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        31|       25| 56
# class=True |        29|       42| 71
#            |        60|       67|127
# ERR = 0.425197
# 40
# -----
# Context OCCPgroup=CON AND AGEPgroup=>60 AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=31-40 AND SEX=Male AND POBPgroup=US
# Size = 40  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        19|        6|25
# class=True |        11|        4|15
#            |        30|       10|40
# ERR = 0.425000
# 106
# -----
# Context OCCPgroup=EDU AND COW=Employee of a private not-for-profit, tax-exempt,or charitable organization AND AGEPgroup=51-60 AND SCHL=Bachelor's degree AND WKHPgroup=>40
# Size = 106  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        24|       31| 55
# class=True |        14|       37| 51
#            |        38|       68|106
# ERR = 0.424528
# 92
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=MGR AND AGEPgroup=31-40 AND WKHPgroup=31-40 AND MAR=Married AND POBPgroup=US
# Size = 92  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|         9|       21|30
# class=True |        18|       44|62
#            |        27|       65|92
# ERR = 0.423913
# 2
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=MGR AND AGEPgroup=31-40 AND WKHPgroup=31-40 AND RAC1P=White alone AND POBPgroup=US
# Size = 2  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         1|        0|1
# class=True |         1|        0|1
#            |         2|        0|2
# ERR = 0.500000
# 92
# -----
# Context COW=Local government employee (city, county, etc.) AND STATE=TX AND SCHL=Bachelor's degree AND WKHPgroup=>40 AND SEX=Female AND MAR=Married
# Size = 92  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|         4|       29|33
# class=True |        10|       49|59
#            |        14|       78|92
# ERR = 0.423913
# 124
# -----
# Context OCCPgroup=EDU AND AGEPgroup=>60 AND SCHL=Bachelor's degree AND WKHPgroup=>40 AND SEX=Female AND POBPgroup=US
# Size = 124  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        15|       35| 50
# class=True |        19|       55| 74
#            |        34|       90|124
# ERR = 0.435484
# 111
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND SCHL=Associate's degree AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male
# Size = 111  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        18|       33| 51
# class=True |        14|       46| 60
#            |        32|       79|111
# ERR = 0.423423
# 78
# -----
# Context OCCPgroup=CLN AND SCHL=Associate's degree AND WKHPgroup=>40 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 78  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|        32|       14|46
# class=True |        19|       13|32
#            |        51|       27|78
# ERR = 0.423077
# 104
# -----
# Context RAC1P=Black or African American alone AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=51-60 AND WKHPgroup=>40 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        21|       22| 43
# class=True |        22|       39| 61
#            |        43|       61|104
# ERR = 0.423077
# 104
# -----
# Context OCCPgroup=RPR AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND AGEPgroup=16-30 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 104  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        44|       12| 56
# class=True |        32|       16| 48
#            |        76|       28|104
# ERR = 0.423077
# 97
# -----
# Context OCCPgroup=RPR AND STATE=MI AND WKHPgroup=31-40 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 97  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        43|       23|66
# class=True |        18|       13|31
#            |        61|       36|97
# ERR = 0.422680
# 97
# -----
# Context OCCPgroup=PRD AND SCHL=1 or more years of college credit, no degree AND WKHPgroup=>40 AND AGEPgroup=16-30 AND SEX=Male AND MAR=Married AND POBPgroup=US
# Size = 97  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        44|        9|53
# class=True |        32|       12|44
#            |        76|       21|97
# ERR = 0.422680
# 97
# -----
# Context SCHL=12th grade - no diploma AND AGEPgroup=>60 AND WKHPgroup=31-40 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 97  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        41|        9|50
# class=True |        32|       15|47
#            |        73|       24|97
# ERR = 0.422680
# 142
# -----
# Context OCCPgroup=FIN AND SCHL=Some college, but less than 1 year AND SEX=Female AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 142  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        51|       18| 69
# class=True |        42|       31| 73
#            |        93|       49|142
# ERR = 0.422535
# 116
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=MGR AND AGEPgroup=41-50 AND SCHL=Bachelor's degree AND WKHPgroup=>40
# Size = 116  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        20|       37| 57
# class=True |        12|       47| 59
#            |        32|       84|116
# ERR = 0.422414
# 90
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND STATE=FL AND SCHL=Some college, but less than 1 year AND MAR=Married AND RAC1P=White alone
# Size = 90  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        33|       17|50
# class=True |        21|       19|40
#            |        54|       36|90
# ERR = 0.422222
# 128
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND OCCPgroup=OFF AND WKHPgroup=>40 AND SEX=Female
# Size = 128  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        58|       21| 79
# class=True |        33|       16| 49
#            |        91|       37|128
# ERR = 0.421875
# 84
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND STATE=FL AND POBPgroup=Americas AND WKHPgroup=>40 AND RAC1P=White alone
# Size = 84  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        19|       19|38
# class=True |        17|       29|46
#            |        36|       48|84
# ERR = 0.428571
# 8
# -----
# Context OCCPgroup=SAL AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Female AND RAC1P=White alone
# Size = 8  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         4|        0|4
# class=True |         4|        0|4
#            |         8|        0|8
# ERR = 0.500000
# 19
# -----
# Context SCHL=Associate's degree AND OCCPgroup=MGR AND AGEPgroup=51-60 AND SEX=Female AND WKHPgroup=31-40 AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 19  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         7|        4|11
# class=True |         4|        4| 8
#            |        11|        8|19
# ERR = 0.421053
# 190
# -----
# Context OCCPgroup=TRN AND STATE=TX AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND MAR=Married
# Size = 190  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        43|       38| 81
# class=True |        42|       67|109
#            |        85|      105|190
# ERR = 0.421053
# 17
# -----
# Context COW=Self-employed in own not incorporated business,professional practice, or farm AND OCCPgroup=TRN AND SCHL=Regular high school diploma AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND RAC1P=White alone
# Size = 17  Perc = 0.00%
#            |pred=False|pred=True|
# class=False|         7|        3|10
# class=True |         5|        2| 7
#            |        12|        5|17
# ERR = 0.470588
# 114
# -----
# Context OCCPgroup=OFF AND STATE=CA AND AGEPgroup=41-50 AND MAR=Never married or under 15 years old AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 114  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        56|       13| 69
# class=True |        35|       10| 45
#            |        91|       23|114
# ERR = 0.421053
# 145
# -----
# Context SCHL=Master's degree AND STATE=CA AND AGEPgroup=16-30 AND SEX=Female AND WKHPgroup=31-40 AND RAC1P=White alone AND POBPgroup=US
# Size = 145  Perc = 0.03%
#            |pred=False|pred=True|
# class=False|        35|       37| 72
# class=True |        24|       49| 73
#            |        59|       86|145
# ERR = 0.420690
# 107
# -----
# Context OCCPgroup=FIN AND SCHL=Associate's degree AND WKHPgroup=>40 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 107  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|         7|       39| 46
# class=True |         6|       55| 61
#            |        13|       94|107
# ERR = 0.420561
# 69
# -----
# Context COW=Self-employed in own incorporated business,professional practice or farm AND SCHL=Associate's degree AND AGEPgroup=51-60 AND SEX=Male AND MAR=Married AND RAC1P=White alone AND POBPgroup=US
# Size = 69  Perc = 0.01%
#            |pred=False|pred=True|
# class=False|         8|       22|30
# class=True |         7|       32|39
#            |        15|       54|69
# ERR = 0.420290
# 128
# -----
# Context OCCPgroup=PRS AND COW=Self-employed in own incorporated business,professional practice or farm AND SEX=Male AND MAR=Married AND POBPgroup=US
# Size = 128  Perc = 0.02%
#            |pred=False|pred=True|
# class=False|        51|       21| 72
# class=True |        33|       23| 56
#            |        84|       44|128
# ERR = 0.421875

# %% [markdown]
# ### Covering ground truth (experimental)

# %%
# filtering condition: return None to filter out, or measure value
# contingency table ctg such that ctg.n() >= minSupp 
'''
     contingency table for inference (unprotected=true.good, n1=a,n2=c)
     ===========
     true.bad      a             
     true.good     c             
     ===========   n()
'''
def check_acc(ctg):
    n = ctg.m1()
    return max(ctg.a,ctg.c)/n if n>0 else None

# %%
# DD(filename or dataframe, unprotectedItem, predBadItem)
disc = dd.DD(census_test[disc_all], unprotectedItem='class=True')    
# confusion matrix
ctg = disc.ctg_any()
disc.print(ctg)
print("ACC = {:f}".format(check_acc(ctg)))
# Out:
# -----
# Context ALL
# Size = 549285  Perc = 100.00%
#            |
# class!=True|346946
# class=True |202339
#            |549285
# ACC = 0.631632

# %%
ctgs_acc = disc.extract(testCond=check_acc, minSupp=-100, topk=1000)

# Top 3
for v, ctg in ctgs_acc[:3]:
    disc.print(ctg)
    print("ERR = {:f}".format(check_acc(ctg)))
# Out:
# -----
# Context STATE=WV AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND RAC1P=White alone AND POBPgroup=US
# Size = 114  Perc = 0.02%
#            |
# class=False|114
# class=True |  0
#            |114
# ERR = 1.000000
# -----
# Context STATE=WV AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 115  Perc = 0.02%
#            |
# class=False|115
# class=True |  0
#            |115
# ERR = 1.000000
# -----
# Context STATE=WV AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND POBPgroup=US
# Size = 125  Perc = 0.02%
#            |
# class=False|125
# class=True |  0
#            |125
# ERR = 1.000000

# %%
def check_acc_abs(ctg):
    n = ctg.m1()
    p = max(ctg.a,ctg.c)/n if n>0 else None
    return None if p is None else dd.Pair( (p*20)//20, p*n)

# sequential covering algorithm: 200 contingency tables
covers, residuals, times, uncovered, ctg_cov, ctg_uncov = \
    disc.cover_n([ctg for _,ctg in ctgs_acc], check_acc_abs, 200, only_protected=False)

# %%
print('== Rejected ==')    
disc.print(ctg_cov) 
tot_err = tot = 0
for ctg, _ in zip(covers, residuals):
    tot_err += check_acc(ctg)*ctg.n()
    tot += ctg.n()
print("ERR = {:f}".format(tot_err/tot))
print('== Selected ==')    
disc.print(ctg_uncov)
print('\n== Cover CTs ==')    
for ctg, res in zip(covers, residuals):
    disc.print(ctg)
    print("ERR = {:f}".format(check_acc(ctg)))
# Out:
# == Rejected ==
# -----
# Context <extensional>
# Size = 14349  Perc = 2.61%
#            |
# class!=True|14109
# class=True |  240
#            |14349
# ERR = 1.000000
# == Selected ==
# -----
# Context <extensional>
# Size = 534936  Perc = 97.39%
#            |
# class!=True|332837
# class=True |202099
#            |534936
#
# == Cover CTs ==
# 355
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND RAC1P=White alone AND POBPgroup=US
# Size = 355  Perc = 0.06%
#            |
# class=False|355
# class=True |  0
#            |355
# ERR = 1.000000
# 299
# -----
# Context STATE=KY AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 299  Perc = 0.05%
#            |
# class=False|299
# class=True |  0
#            |299
# ERR = 1.000000
# 274
# -----
# Context STATE=UT AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 274  Perc = 0.05%
#            |
# class=False|274
# class=True |  0
#            |274
# ERR = 1.000000
# 249
# -----
# Context STATE=IA AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 249  Perc = 0.05%
#            |
# class=False|249
# class=True |  0
#            |249
# ERR = 1.000000
# 247
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 247  Perc = 0.04%
#            |
# class=False|247
# class=True |  0
#            |247
# ERR = 1.000000
# 233
# -----
# Context STATE=LA AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 233  Perc = 0.04%
#            |
# class=False|233
# class=True |  0
#            |233
# ERR = 1.000000
# 223
# -----
# Context STATE=AL AND OCCPgroup=EAT AND SEX=Female
# Size = 223  Perc = 0.04%
#            |
# class=False|223
# class=True |  0
#            |223
# ERR = 1.000000
# 222
# -----
# Context STATE=OK AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old
# Size = 222  Perc = 0.04%
#            |
# class=False|222
# class=True |  0
#            |222
# ERR = 1.000000
# 215
# -----
# Context STATE=KS AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 215  Perc = 0.04%
#            |
# class=False|215
# class=True |  0
#            |215
# ERR = 1.000000
# 213
# -----
# Context SCHL=Grade 10 AND OCCPgroup=EAT AND WKHPgroup=11-20 AND POBPgroup=US
# Size = 213  Perc = 0.04%
#            |
# class=False|213
# class=True |  0
#            |213
# ERR = 1.000000
# 211
# -----
# Context STATE=KS AND WKHPgroup=21-30 AND AGEPgroup=16-30
# Size = 211  Perc = 0.04%
#            |
# class=False|211
# class=True |  0
#            |211
# ERR = 1.000000
# 206
# -----
# Context STATE=CO AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Female
# Size = 206  Perc = 0.04%
#            |
# class=False|206
# class=True |  0
#            |206
# ERR = 1.000000
# 205
# -----
# Context STATE=VA AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 205  Perc = 0.04%
#            |
# class=False|205
# class=True |  0
#            |205
# ERR = 1.000000
# 192
# -----
# Context STATE=AL AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND POBPgroup=US
# Size = 192  Perc = 0.03%
#            |
# class=False|192
# class=True |  0
#            |192
# ERR = 1.000000
# 188
# -----
# Context STATE=OK AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 188  Perc = 0.03%
#            |
# class=False|188
# class=True |  0
#            |188
# ERR = 1.000000
# 182
# -----
# Context STATE=LA AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 182  Perc = 0.03%
#            |
# class=False|182
# class=True |  0
#            |182
# ERR = 1.000000
# 172
# -----
# Context SCHL=Grade 10 AND OCCPgroup=EAT AND WKHPgroup=21-30
# Size = 172  Perc = 0.03%
#            |
# class=False|172
# class=True |  0
#            |172
# ERR = 1.000000
# 171
# -----
# Context STATE=MS AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 171  Perc = 0.03%
#            |
# class=False|171
# class=True |  0
#            |171
# ERR = 1.000000
# 170
# -----
# Context OCCPgroup=FFF AND RAC1P=Some Other Race alone AND AGEPgroup=16-30
# Size = 170  Perc = 0.03%
#            |
# class=False|170
# class=True |  0
#            |170
# ERR = 1.000000
# 169
# -----
# Context STATE=IA AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 169  Perc = 0.03%
#            |
# class=False|169
# class=True |  0
#            |169
# ERR = 1.000000
# 168
# -----
# Context STATE=AL AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 168  Perc = 0.03%
#            |
# class=False|168
# class=True |  0
#            |168
# ERR = 1.000000
# 165
# -----
# Context STATE=PR AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 165  Perc = 0.03%
#            |
# class=False|165
# class=True |  0
#            |165
# ERR = 1.000000
# 165
# -----
# Context STATE=AZ AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 165  Perc = 0.03%
#            |
# class=False|165
# class=True |  0
#            |165
# ERR = 1.000000
# 160
# -----
# Context OCCPgroup=FFF AND POBPgroup=Americas AND SEX=Female AND MAR=Married AND RAC1P=White alone
# Size = 160  Perc = 0.03%
#            |
# class=False|160
# class=True |  0
#            |160
# ERR = 1.000000
# 157
# -----
# Context STATE=PR AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old
# Size = 157  Perc = 0.03%
#            |
# class=False|157
# class=True |  0
#            |157
# ERR = 1.000000
# 155
# -----
# Context STATE=IA AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 155  Perc = 0.03%
#            |
# class=False|155
# class=True |  0
#            |155
# ERR = 1.000000
# 154
# -----
# Context STATE=AZ AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 154  Perc = 0.03%
#            |
# class=False|154
# class=True |  0
#            |154
# ERR = 1.000000
# 153
# -----
# Context STATE=KY AND OCCPgroup=EAT AND AGEPgroup=16-30
# Size = 153  Perc = 0.03%
#            |
# class=False|153
# class=True |  0
#            |153
# ERR = 1.000000
# 149
# -----
# Context STATE=UT AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 149  Perc = 0.03%
#            |
# class=False|149
# class=True |  0
#            |149
# ERR = 1.000000
# 145
# -----
# Context STATE=MS AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 145  Perc = 0.03%
#            |
# class=False|145
# class=True |  0
#            |145
# ERR = 1.000000
# 144
# -----
# Context STATE=NE AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old
# Size = 144  Perc = 0.03%
#            |
# class=False|144
# class=True |  0
#            |144
# ERR = 1.000000
# 139
# -----
# Context STATE=VA AND WKHPgroup=0-10 AND AGEPgroup=16-30 AND SEX=Female AND POBPgroup=US
# Size = 139  Perc = 0.03%
#            |
# class=False|139
# class=True |  0
#            |139
# ERR = 1.000000
# 136
# -----
# Context COW=Working without pay in family business or farm AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 136  Perc = 0.02%
#            |
# class=False|136
# class=True |  0
#            |136
# ERR = 1.000000
# 134
# -----
# Context OCCPgroup=MIL AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND WKHPgroup=31-40 AND SEX=Male
# Size = 134  Perc = 0.02%
#            |
# class=False|134
# class=True |  0
#            |134
# ERR = 1.000000
# 127
# -----
# Context STATE=AR AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND SEX=Female
# Size = 127  Perc = 0.02%
#            |
# class=False|127
# class=True |  0
#            |127
# ERR = 1.000000
# 126
# -----
# Context SCHL=Grade 9 AND OCCPgroup=EAT AND AGEPgroup=16-30
# Size = 126  Perc = 0.02%
#            |
# class=False|126
# class=True |  0
#            |126
# ERR = 1.000000
# 125
# -----
# Context STATE=CO AND SCHL=Grade 11 AND AGEPgroup=16-30
# Size = 125  Perc = 0.02%
#            |
# class=False|125
# class=True |  0
#            |125
# ERR = 1.000000
# 125
# -----
# Context OCCPgroup=SCI AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 125  Perc = 0.02%
#            |
# class=False|125
# class=True |  0
#            |125
# ERR = 1.000000
# 124
# -----
# Context STATE=WV AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old
# Size = 124  Perc = 0.02%
#            |
# class=False|124
# class=True |  0
#            |124
# ERR = 1.000000
# 124
# -----
# Context RAC1P=American Indian alone AND WKHPgroup=21-30 AND AGEPgroup=16-30
# Size = 124  Perc = 0.02%
#            |
# class=False|124
# class=True |  0
#            |124
# ERR = 1.000000
# 121
# -----
# Context OCCPgroup=FFF AND RAC1P=Some Other Race alone AND AGEPgroup=31-40
# Size = 121  Perc = 0.02%
#            |
# class=False|121
# class=True |  0
#            |121
# ERR = 1.000000
# 121
# -----
# Context SCHL=Grade 10 AND OCCPgroup=PRS AND MAR=Never married or under 15 years old
# Size = 121  Perc = 0.02%
#            |
# class=False|121
# class=True |  0
#            |121
# ERR = 1.000000
# 119
# -----
# Context POBPgroup=Africa AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 119  Perc = 0.02%
#            |
# class=False|119
# class=True |  0
#            |119
# ERR = 1.000000
# 119
# -----
# Context STATE=VA AND COW=Federal government employee AND SCHL=Master's degree AND WKHPgroup=>40 AND POBPgroup=US
# Size = 119  Perc = 0.02%
#            |
# class=False|  0
# class=True |119
#            |119
# ERR = 1.000000
# 117
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND AGEPgroup=16-30 AND SEX=Male AND POBPgroup=US
# Size = 117  Perc = 0.02%
#            |
# class=False|117
# class=True |  0
#            |117
# ERR = 1.000000
# 115
# -----
# Context STATE=CO AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 115  Perc = 0.02%
#            |
# class=False|115
# class=True |  0
#            |115
# ERR = 1.000000
# 114
# -----
# Context STATE=AL AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 114  Perc = 0.02%
#            |
# class=False|114
# class=True |  0
#            |114
# ERR = 1.000000
# 113
# -----
# Context SCHL=Grade 9 AND WKHPgroup=11-20 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 113  Perc = 0.02%
#            |
# class=False|113
# class=True |  0
#            |113
# ERR = 1.000000
# 113
# -----
# Context OCCPgroup=FIN AND SCHL=Master's degree AND AGEPgroup=31-40 AND WKHPgroup=>40 AND SEX=Male AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 113  Perc = 0.02%
#            |
# class=False|  0
# class=True |113
#            |113
# ERR = 1.000000
# 111
# -----
# Context STATE=KS AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old
# Size = 111  Perc = 0.02%
#            |
# class=False|111
# class=True |  0
#            |111
# ERR = 1.000000
# 110
# -----
# Context STATE=NE AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 110  Perc = 0.02%
#            |
# class=False|110
# class=True |  0
#            |110
# ERR = 1.000000
# 108
# -----
# Context STATE=AR AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND RAC1P=White alone
# Size = 108  Perc = 0.02%
#            |
# class=False|108
# class=True |  0
#            |108
# ERR = 1.000000
# 108
# -----
# Context SCHL=Grade 9 AND WKHPgroup=21-30 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 108  Perc = 0.02%
#            |
# class=False|108
# class=True |  0
#            |108
# ERR = 1.000000
# 108
# -----
# Context OCCPgroup=FFF AND AGEPgroup=16-30 AND SEX=Female AND WKHPgroup=31-40
# Size = 108  Perc = 0.02%
#            |
# class=False|108
# class=True |  0
#            |108
# ERR = 1.000000
# 108
# -----
# Context STATE=VA AND RAC1P=Black or African American alone AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 108  Perc = 0.02%
#            |
# class=False|108
# class=True |  0
#            |108
# ERR = 1.000000
# 106
# -----
# Context STATE=LA AND OCCPgroup=EAT AND SEX=Female AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 106  Perc = 0.02%
#            |
# class=False|106
# class=True |  0
#            |106
# ERR = 1.000000
# 105
# -----
# Context RAC1P=American Indian alone AND OCCPgroup=HLS AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 105  Perc = 0.02%
#            |
# class=False|105
# class=True |  0
#            |105
# ERR = 1.000000
# 104
# -----
# Context STATE=UT AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 104  Perc = 0.02%
#            |
# class=False|104
# class=True |  0
#            |104
# ERR = 1.000000
# 103
# -----
# Context STATE=IA AND OCCPgroup=EAT AND WKHPgroup=31-40
# Size = 103  Perc = 0.02%
#            |
# class=False|103
# class=True |  0
#            |103
# ERR = 1.000000
# 102
# -----
# Context STATE=AR AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 102  Perc = 0.02%
#            |
# class=False|102
# class=True |  0
#            |102
# ERR = 1.000000
# 101
# -----
# Context STATE=KY AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 101  Perc = 0.02%
#            |
# class=False|101
# class=True |  0
#            |101
# ERR = 1.000000
# 101
# -----
# Context STATE=AL AND SCHL=Regular high school diploma AND MAR=Never married or under 15 years old AND SEX=Female AND WKHPgroup=31-40
# Size = 101  Perc = 0.02%
#            |
# class=False|101
# class=True |  0
#            |101
# ERR = 1.000000
# 100
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND SEX=Female AND MAR=Married AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 100  Perc = 0.02%
#            |
# class=False|100
# class=True |  0
#            |100
# ERR = 1.000000
# 99
# -----
# Context STATE=PR AND OCCPgroup=OFF AND MAR=Never married or under 15 years old
# Size = 99  Perc = 0.02%
#            |
# class=False|99
# class=True | 0
#            |99
# ERR = 1.000000
# 96
# -----
# Context STATE=LA AND OCCPgroup=HLS AND RAC1P=Black or African American alone AND SEX=Female
# Size = 96  Perc = 0.02%
#            |
# class=False|96
# class=True | 0
#            |96
# ERR = 1.000000
# 95
# -----
# Context STATE=NM AND WKHPgroup=21-30 AND AGEPgroup=16-30
# Size = 95  Perc = 0.02%
#            |
# class=False|95
# class=True | 0
#            |95
# ERR = 1.000000
# 95
# -----
# Context STATE=ID AND WKHPgroup=11-20 AND AGEPgroup=16-30
# Size = 95  Perc = 0.02%
#            |
# class=False|95
# class=True | 0
#            |95
# ERR = 1.000000
# 95
# -----
# Context RAC1P=American Indian alone AND OCCPgroup=CLN AND SEX=Female AND POBPgroup=US
# Size = 95  Perc = 0.02%
#            |
# class=False|95
# class=True | 0
#            |95
# ERR = 1.000000
# 91
# -----
# Context OCCPgroup=FFF AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 91  Perc = 0.02%
#            |
# class=False|91
# class=True | 0
#            |91
# ERR = 1.000000
# 91
# -----
# Context STATE=VA AND OCCPgroup=CLN AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 91  Perc = 0.02%
#            |
# class=False|91
# class=True | 0
#            |91
# ERR = 1.000000
# 90
# -----
# Context STATE=KY AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 90  Perc = 0.02%
#            |
# class=False|90
# class=True | 0
#            |90
# ERR = 1.000000
# 88
# -----
# Context STATE=PR AND SCHL=Regular high school diploma AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 88  Perc = 0.02%
#            |
# class=False|88
# class=True | 0
#            |88
# ERR = 1.000000
# 88
# -----
# Context SCHL=Grade 9 AND POBPgroup=Americas AND STATE=TX AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 88  Perc = 0.02%
#            |
# class=False|88
# class=True | 0
#            |88
# ERR = 1.000000
# 87
# -----
# Context STATE=CO AND OCCPgroup=EAT AND WKHPgroup=21-30
# Size = 87  Perc = 0.02%
#            |
# class=False|87
# class=True | 0
#            |87
# ERR = 1.000000
# 87
# -----
# Context OCCPgroup=FFF AND STATE=CA AND MAR=Never married or under 15 years old AND WKHPgroup=31-40 AND SEX=Male
# Size = 87  Perc = 0.02%
#            |
# class=False|87
# class=True | 0
#            |87
# ERR = 1.000000
# 87
# -----
# Context STATE=AZ AND OCCPgroup=PRS AND MAR=Never married or under 15 years old
# Size = 87  Perc = 0.02%
#            |
# class=False|87
# class=True | 0
#            |87
# ERR = 1.000000
# 84
# -----
# Context STATE=AZ AND OCCPgroup=CLN AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 84  Perc = 0.02%
#            |
# class=False|84
# class=True | 0
#            |84
# ERR = 1.000000
# 83
# -----
# Context STATE=OK AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female AND POBPgroup=US
# Size = 83  Perc = 0.02%
#            |
# class=False|83
# class=True | 0
#            |83
# ERR = 1.000000
# 82
# -----
# Context OCCPgroup=FFF AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 82  Perc = 0.01%
#            |
# class=False|82
# class=True | 0
#            |82
# ERR = 1.000000
# 79
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Female AND POBPgroup=US
# Size = 79  Perc = 0.01%
#            |
# class=False|79
# class=True | 0
#            |79
# ERR = 1.000000
# 79
# -----
# Context SCHL=Grade 10 AND STATE=OH AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 79  Perc = 0.01%
#            |
# class=False|79
# class=True | 0
#            |79
# ERR = 1.000000
# 76
# -----
# Context STATE=AZ AND OCCPgroup=OFF AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30 AND POBPgroup=US
# Size = 76  Perc = 0.01%
#            |
# class=False|76
# class=True | 0
#            |76
# ERR = 1.000000
# 74
# -----
# Context STATE=VA AND WKHPgroup=21-30 AND SCHL=1 or more years of college credit, no degree AND MAR=Never married or under 15 years old
# Size = 74  Perc = 0.01%
#            |
# class=False|74
# class=True | 0
#            |74
# ERR = 1.000000
# 68
# -----
# Context STATE=UT AND OCCPgroup=EAT AND MAR=Never married or under 15 years old
# Size = 68  Perc = 0.01%
#            |
# class=False|68
# class=True | 0
#            |68
# ERR = 1.000000
# 68
# -----
# Context STATE=VA AND OCCPgroup=EAT AND MAR=Never married or under 15 years old AND SEX=Female AND RAC1P=White alone
# Size = 68  Perc = 0.01%
#            |
# class=False|68
# class=True | 0
#            |68
# ERR = 1.000000
# 66
# -----
# Context STATE=MS AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND SEX=Female
# Size = 66  Perc = 0.01%
#            |
# class=False|66
# class=True | 0
#            |66
# ERR = 1.000000
# 65
# -----
# Context STATE=AZ AND WKHPgroup=0-10 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 65  Perc = 0.01%
#            |
# class=False|65
# class=True | 0
#            |65
# ERR = 1.000000
# 64
# -----
# Context SCHL=Grade 9 AND OCCPgroup=CLN AND POBPgroup=Americas AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 64  Perc = 0.01%
#            |
# class=False|64
# class=True | 0
#            |64
# ERR = 1.000000
# 62
# -----
# Context STATE=PR AND OCCPgroup=SAL AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 62  Perc = 0.01%
#            |
# class=False|62
# class=True | 0
#            |62
# ERR = 1.000000
# 62
# -----
# Context STATE=AL AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 62  Perc = 0.01%
#            |
# class=False|62
# class=True | 0
#            |62
# ERR = 1.000000
# 60
# -----
# Context STATE=MS AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female AND POBPgroup=US
# Size = 60  Perc = 0.01%
#            |
# class=False|60
# class=True | 0
#            |60
# ERR = 1.000000
# 60
# -----
# Context SCHL=Grade 9 AND WKHPgroup=21-30 AND AGEPgroup=16-30
# Size = 60  Perc = 0.01%
#            |
# class=False|60
# class=True | 0
#            |60
# ERR = 1.000000
# 58
# -----
# Context STATE=UT AND OCCPgroup=OFF AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 58  Perc = 0.01%
#            |
# class=False|58
# class=True | 0
#            |58
# ERR = 1.000000
# 57
# -----
# Context OCCPgroup=FFF AND POBPgroup=Americas AND SCHL=Regular high school diploma AND WKHPgroup=31-40
# Size = 57  Perc = 0.01%
#            |
# class=False|57
# class=True | 0
#            |57
# ERR = 1.000000
# 56
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND SCHL=Regular high school diploma AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 56  Perc = 0.01%
#            |
# class=False|56
# class=True | 0
#            |56
# ERR = 1.000000
# 56
# -----
# Context STATE=AZ AND SCHL=Grade 11 AND AGEPgroup=16-30
# Size = 56  Perc = 0.01%
#            |
# class=False|56
# class=True | 0
#            |56
# ERR = 1.000000
# 55
# -----
# Context STATE=AR AND OCCPgroup=EAT AND MAR=Never married or under 15 years old
# Size = 55  Perc = 0.01%
#            |
# class=False|55
# class=True | 0
#            |55
# ERR = 1.000000
# 52
# -----
# Context STATE=UT AND WKHPgroup=11-20 AND SCHL=1 or more years of college credit, no degree AND SEX=Female
# Size = 52  Perc = 0.01%
#            |
# class=False|52
# class=True | 0
#            |52
# ERR = 1.000000
# 49
# -----
# Context COW=Working without pay in family business or farm AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 49  Perc = 0.01%
#            |
# class=False|49
# class=True | 0
#            |49
# ERR = 1.000000
# 48
# -----
# Context STATE=AZ AND WKHPgroup=21-30 AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30
# Size = 48  Perc = 0.01%
#            |
# class=False|48
# class=True | 0
#            |48
# ERR = 1.000000
# 48
# -----
# Context STATE=IA AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 48  Perc = 0.01%
#            |
# class=False|48
# class=True | 0
#            |48
# ERR = 1.000000
# 48
# -----
# Context STATE=VA AND WKHPgroup=21-30 AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 48  Perc = 0.01%
#            |
# class=False|48
# class=True | 0
#            |48
# ERR = 1.000000
# 48
# -----
# Context STATE=KS AND OCCPgroup=EAT AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 48  Perc = 0.01%
#            |
# class=False|48
# class=True | 0
#            |48
# ERR = 1.000000
# 46
# -----
# Context OCCPgroup=FFF AND SCHL=Grade 11 AND AGEPgroup=16-30 AND RAC1P=White alone AND POBPgroup=US
# Size = 46  Perc = 0.01%
#            |
# class=False|46
# class=True | 0
#            |46
# ERR = 1.000000
# 46
# -----
# Context STATE=AL AND OCCPgroup=EAT AND WKHPgroup=31-40 AND POBPgroup=US
# Size = 46  Perc = 0.01%
#            |
# class=False|46
# class=True | 0
#            |46
# ERR = 1.000000
# 45
# -----
# Context STATE=OK AND OCCPgroup=EAT AND AGEPgroup=16-30 AND SEX=Female
# Size = 45  Perc = 0.01%
#            |
# class=False|45
# class=True | 0
#            |45
# ERR = 1.000000
# 44
# -----
# Context STATE=PR AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30
# Size = 44  Perc = 0.01%
#            |
# class=False|44
# class=True | 0
#            |44
# ERR = 1.000000
# 43
# -----
# Context STATE=PR AND WKHPgroup=21-30 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 43  Perc = 0.01%
#            |
# class=False|43
# class=True | 0
#            |43
# ERR = 1.000000
# 42
# -----
# Context SCHL=Grade 9 AND OCCPgroup=EAT AND SEX=Male AND POBPgroup=US
# Size = 42  Perc = 0.01%
#            |
# class=False|42
# class=True | 0
#            |42
# ERR = 1.000000
# 42
# -----
# Context STATE=AZ AND WKHPgroup=21-30 AND SCHL=Regular high school diploma AND AGEPgroup=16-30
# Size = 42  Perc = 0.01%
#            |
# class=False|42
# class=True | 0
#            |42
# ERR = 1.000000
# 42
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND RAC1P=Black or African American alone AND MAR=Never married or under 15 years old
# Size = 42  Perc = 0.01%
#            |
# class=False|42
# class=True | 0
#            |42
# ERR = 1.000000
# 41
# -----
# Context STATE=AL AND RAC1P=Black or African American alone AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old
# Size = 41  Perc = 0.01%
#            |
# class=False|41
# class=True | 0
#            |41
# ERR = 1.000000
# 41
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Female
# Size = 41  Perc = 0.01%
#            |
# class=False|41
# class=True | 0
#            |41
# ERR = 1.000000
# 39
# -----
# Context STATE=MS AND OCCPgroup=SAL AND MAR=Never married or under 15 years old AND SEX=Female AND POBPgroup=US
# Size = 39  Perc = 0.01%
#            |
# class=False|39
# class=True | 0
#            |39
# ERR = 1.000000
# 38
# -----
# Context STATE=PR AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 38  Perc = 0.01%
#            |
# class=False|38
# class=True | 0
#            |38
# ERR = 1.000000
# 38
# -----
# Context OCCPgroup=FFF AND POBPgroup=Americas AND STATE=CA AND MAR=Never married or under 15 years old AND SEX=Male
# Size = 38  Perc = 0.01%
#            |
# class=False|38
# class=True | 0
#            |38
# ERR = 1.000000
# 36
# -----
# Context STATE=VA AND OCCPgroup=EAT AND WKHPgroup=11-20
# Size = 36  Perc = 0.01%
#            |
# class=False|36
# class=True | 0
#            |36
# ERR = 1.000000
# 32
# -----
# Context STATE=PR AND OCCPgroup=EAT AND MAR=Never married or under 15 years old
# Size = 32  Perc = 0.01%
#            |
# class=False|32
# class=True | 0
#            |32
# ERR = 1.000000
# 32
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Male AND RAC1P=White alone
# Size = 32  Perc = 0.01%
#            |
# class=False|32
# class=True | 0
#            |32
# ERR = 1.000000
# 31
# -----
# Context STATE=OK AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND RAC1P=White alone
# Size = 31  Perc = 0.01%
#            |
# class=False|31
# class=True | 0
#            |31
# ERR = 1.000000
# 31
# -----
# Context STATE=IA AND OCCPgroup=EAT AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 31  Perc = 0.01%
#            |
# class=False|31
# class=True | 0
#            |31
# ERR = 1.000000
# 30
# -----
# Context STATE=LA AND OCCPgroup=EAT AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 30  Perc = 0.01%
#            |
# class=False|30
# class=True | 0
#            |30
# ERR = 1.000000
# 29
# -----
# Context STATE=KY AND WKHPgroup=11-20 AND OCCPgroup=SAL AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 29  Perc = 0.01%
#            |
# class=False|29
# class=True | 0
#            |29
# ERR = 1.000000
# 25
# -----
# Context STATE=PR AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 25  Perc = 0.00%
#            |
# class=False|25
# class=True | 0
#            |25
# ERR = 1.000000
# 25
# -----
# Context OCCPgroup=FFF AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND SEX=Female
# Size = 25  Perc = 0.00%
#            |
# class=False|25
# class=True | 0
#            |25
# ERR = 1.000000
# 25
# -----
# Context STATE=VA AND OCCPgroup=EAT AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30
# Size = 25  Perc = 0.00%
#            |
# class=False|25
# class=True | 0
#            |25
# ERR = 1.000000
# 24
# -----
# Context STATE=UT AND SCHL=Grade 11 AND MAR=Never married or under 15 years old
# Size = 24  Perc = 0.00%
#            |
# class=False|24
# class=True | 0
#            |24
# ERR = 1.000000
# 24
# -----
# Context OCCPgroup=FFF AND POBPgroup=Americas AND AGEPgroup=31-40 AND SEX=Female
# Size = 24  Perc = 0.00%
#            |
# class=False|24
# class=True | 0
#            |24
# ERR = 1.000000
# 24
# -----
# Context STATE=AL AND SCHL=1 or more years of college credit, no degree AND MAR=Never married or under 15 years old AND SEX=Female AND RAC1P=White alone
# Size = 24  Perc = 0.00%
#            |
# class=False|24
# class=True | 0
#            |24
# ERR = 1.000000
# 23
# -----
# Context OCCPgroup=FFF AND STATE=CA AND SCHL=Regular high school diploma AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 23  Perc = 0.00%
#            |
# class=False|23
# class=True | 0
#            |23
# ERR = 1.000000
# 22
# -----
# Context RAC1P=American Indian alone AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 22  Perc = 0.00%
#            |
# class=False|22
# class=True | 0
#            |22
# ERR = 1.000000
# 22
# -----
# Context STATE=VA AND RAC1P=Black or African American alone AND WKHPgroup=21-30 AND AGEPgroup=16-30
# Size = 22  Perc = 0.00%
#            |
# class=False|22
# class=True | 0
#            |22
# ERR = 1.000000
# 21
# -----
# Context OCCPgroup=FFF AND POBPgroup=Americas AND STATE=CA AND AGEPgroup=16-30
# Size = 21  Perc = 0.00%
#            |
# class=False|21
# class=True | 0
#            |21
# ERR = 1.000000
# 21
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND OCCPgroup=SAL AND MAR=Never married or under 15 years old
# Size = 21  Perc = 0.00%
#            |
# class=False|21
# class=True | 0
#            |21
# ERR = 1.000000
# 20
# -----
# Context STATE=LA AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Female
# Size = 20  Perc = 0.00%
#            |
# class=False|20
# class=True | 0
#            |20
# ERR = 1.000000
# 19
# -----
# Context STATE=AR AND OCCPgroup=EAT AND AGEPgroup=16-30 AND POBPgroup=US
# Size = 19  Perc = 0.00%
#            |
# class=False|19
# class=True | 0
#            |19
# ERR = 1.000000
# 19
# -----
# Context STATE=AL AND SCHL=Regular high school diploma AND MAR=Never married or under 15 years old AND SEX=Female AND RAC1P=White alone
# Size = 19  Perc = 0.00%
#            |
# class=False|19
# class=True | 0
#            |19
# ERR = 1.000000
# 19
# -----
# Context STATE=AZ AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 19  Perc = 0.00%
#            |
# class=False|19
# class=True | 0
#            |19
# ERR = 1.000000
# 19
# -----
# Context STATE=VA AND OCCPgroup=EAT AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND POBPgroup=US
# Size = 19  Perc = 0.00%
#            |
# class=False|19
# class=True | 0
#            |19
# ERR = 1.000000
# 17
# -----
# Context STATE=OK AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 17  Perc = 0.00%
#            |
# class=False|17
# class=True | 0
#            |17
# ERR = 1.000000
# 17
# -----
# Context STATE=KY AND OCCPgroup=EAT AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 17  Perc = 0.00%
#            |
# class=False|17
# class=True | 0
#            |17
# ERR = 1.000000
# 16
# -----
# Context POBPgroup=Africa AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 16  Perc = 0.00%
#            |
# class=False|16
# class=True | 0
#            |16
# ERR = 1.000000
# 16
# -----
# Context STATE=KY AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 16  Perc = 0.00%
#            |
# class=False|16
# class=True | 0
#            |16
# ERR = 1.000000
# 16
# -----
# Context STATE=KY AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Female AND POBPgroup=US
# Size = 16  Perc = 0.00%
#            |
# class=False|16
# class=True | 0
#            |16
# ERR = 1.000000
# 16
# -----
# Context OCCPgroup=FFF AND RAC1P=Some Other Race alone AND STATE=CA AND MAR=Never married or under 15 years old
# Size = 16  Perc = 0.00%
#            |
# class=False|16
# class=True | 0
#            |16
# ERR = 1.000000
# 16
# -----
# Context STATE=KS AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 16  Perc = 0.00%
#            |
# class=False|16
# class=True | 0
#            |16
# ERR = 1.000000
# 15
# -----
# Context COW=Working without pay in family business or farm AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 15  Perc = 0.00%
#            |
# class=False|15
# class=True | 0
#            |15
# ERR = 1.000000
# 15
# -----
# Context STATE=MS AND OCCPgroup=SAL AND AGEPgroup=16-30 AND SEX=Female AND POBPgroup=US
# Size = 15  Perc = 0.00%
#            |
# class=False|15
# class=True | 0
#            |15
# ERR = 1.000000
# 15
# -----
# Context STATE=AL AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 15  Perc = 0.00%
#            |
# class=False|15
# class=True | 0
#            |15
# ERR = 1.000000
# 15
# -----
# Context STATE=LA AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 15  Perc = 0.00%
#            |
# class=False|15
# class=True | 0
#            |15
# ERR = 1.000000
# 14
# -----
# Context STATE=PR AND SCHL=1 or more years of college credit, no degree AND MAR=Never married or under 15 years old AND SEX=Female AND POBPgroup=US
# Size = 14  Perc = 0.00%
#            |
# class=False|14
# class=True | 0
#            |14
# ERR = 1.000000
# 14
# -----
# Context STATE=PR AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 14  Perc = 0.00%
#            |
# class=False|14
# class=True | 0
#            |14
# ERR = 1.000000
# 14
# -----
# Context STATE=KS AND OCCPgroup=EAT AND AGEPgroup=16-30 AND POBPgroup=US
# Size = 14  Perc = 0.00%
#            |
# class=False|14
# class=True | 0
#            |14
# ERR = 1.000000
# 13
# -----
# Context STATE=UT AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Male
# Size = 13  Perc = 0.00%
#            |
# class=False|13
# class=True | 0
#            |13
# ERR = 1.000000
# 13
# -----
# Context SCHL=Grade 9 AND OCCPgroup=EAT AND MAR=Never married or under 15 years old AND RAC1P=White alone
# Size = 13  Perc = 0.00%
#            |
# class=False|13
# class=True | 0
#            |13
# ERR = 1.000000
# 13
# -----
# Context STATE=IA AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 13  Perc = 0.00%
#            |
# class=False|13
# class=True | 0
#            |13
# ERR = 1.000000
# 12
# -----
# Context STATE=PR AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND POBPgroup=US
# Size = 12  Perc = 0.00%
#            |
# class=False|12
# class=True | 0
#            |12
# ERR = 1.000000
# 12
# -----
# Context STATE=KS AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 12  Perc = 0.00%
#            |
# class=False|12
# class=True | 0
#            |12
# ERR = 1.000000
# 11
# -----
# Context STATE=WV AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND RAC1P=White alone AND POBPgroup=US
# Size = 11  Perc = 0.00%
#            |
# class=False|11
# class=True | 0
#            |11
# ERR = 1.000000
# 11
# -----
# Context STATE=AL AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old
# Size = 11  Perc = 0.00%
#            |
# class=False|11
# class=True | 0
#            |11
# ERR = 1.000000
# 11
# -----
# Context STATE=AL AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND SEX=Male
# Size = 11  Perc = 0.00%
#            |
# class=False|11
# class=True | 0
#            |11
# ERR = 1.000000
# 11
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Female AND RAC1P=White alone AND POBPgroup=US
# Size = 11  Perc = 0.00%
#            |
# class=False|11
# class=True | 0
#            |11
# ERR = 1.000000
# 11
# -----
# Context STATE=LA AND OCCPgroup=EAT AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 11  Perc = 0.00%
#            |
# class=False|11
# class=True | 0
#            |11
# ERR = 1.000000
# 10
# -----
# Context POBPgroup=Africa AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 10  Perc = 0.00%
#            |
# class=False|10
# class=True | 0
#            |10
# ERR = 1.000000
# 10
# -----
# Context OCCPgroup=FFF AND WKHPgroup=0-10 AND AGEPgroup=16-30
# Size = 10  Perc = 0.00%
#            |
# class=False|10
# class=True | 0
#            |10
# ERR = 1.000000
# 10
# -----
# Context STATE=AL AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 10  Perc = 0.00%
#            |
# class=False|10
# class=True | 0
#            |10
# ERR = 1.000000
# 10
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND SCHL=1 or more years of college credit, no degree AND MAR=Never married or under 15 years old
# Size = 10  Perc = 0.00%
#            |
# class=False|10
# class=True | 0
#            |10
# ERR = 1.000000
# 9
# -----
# Context STATE=IA AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Male
# Size = 9  Perc = 0.00%
#            |
# class=False|9
# class=True |0
#            |9
# ERR = 1.000000
# 8
# -----
# Context STATE=PR AND OCCPgroup=SAL AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 8  Perc = 0.00%
#            |
# class=False|8
# class=True |0
#            |8
# ERR = 1.000000
# 8
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND SCHL=Regular high school diploma AND RAC1P=White alone AND POBPgroup=US
# Size = 8  Perc = 0.00%
#            |
# class=False|8
# class=True |0
#            |8
# ERR = 1.000000
# 8
# -----
# Context STATE=AZ AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND POBPgroup=US
# Size = 8  Perc = 0.00%
#            |
# class=False|8
# class=True |0
#            |8
# ERR = 1.000000
# 8
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND SCHL=1 or more years of college credit, no degree AND MAR=Never married or under 15 years old
# Size = 8  Perc = 0.00%
#            |
# class=False|8
# class=True |0
#            |8
# ERR = 1.000000
# 8
# -----
# Context STATE=VA AND COW=Federal government employee AND SCHL=Master's degree AND WKHPgroup=>40 AND RAC1P=White alone
# Size = 8  Perc = 0.00%
#            |
# class=False|0
# class=True |8
#            |8
# ERR = 1.000000
# 8
# -----
# Context SCHL=Grade 10 AND OCCPgroup=EAT AND WKHPgroup=11-20 AND SEX=Male
# Size = 8  Perc = 0.00%
#            |
# class=False|8
# class=True |0
#            |8
# ERR = 1.000000
# 7
# -----
# Context STATE=UT AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old AND POBPgroup=US
# Size = 7  Perc = 0.00%
#            |
# class=False|7
# class=True |0
#            |7
# ERR = 1.000000
# 7
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 7  Perc = 0.00%
#            |
# class=False|7
# class=True |0
#            |7
# ERR = 1.000000
# 7
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND WKHPgroup=11-20 AND POBPgroup=US
# Size = 7  Perc = 0.00%
#            |
# class=False|7
# class=True |0
#            |7
# ERR = 1.000000
# 7
# -----
# Context STATE=VA AND WKHPgroup=21-30 AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30
# Size = 7  Perc = 0.00%
#            |
# class=False|7
# class=True |0
#            |7
# ERR = 1.000000
# 6
# -----
# Context SCHL=Grade 9 AND OCCPgroup=EAT AND MAR=Never married or under 15 years old AND POBPgroup=US
# Size = 6  Perc = 0.00%
#            |
# class=False|6
# class=True |0
#            |6
# ERR = 1.000000
# 6
# -----
# Context STATE=KS AND WKHPgroup=21-30 AND MAR=Never married or under 15 years old AND SEX=Female
# Size = 6  Perc = 0.00%
#            |
# class=False|6
# class=True |0
#            |6
# ERR = 1.000000
# 5
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 5  Perc = 0.00%
#            |
# class=False|5
# class=True |0
#            |5
# ERR = 1.000000
# 5
# -----
# Context STATE=AZ AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND SEX=Female AND RAC1P=White alone AND POBPgroup=US
# Size = 5  Perc = 0.00%
#            |
# class=False|5
# class=True |0
#            |5
# ERR = 1.000000
# 5
# -----
# Context STATE=IA AND WKHPgroup=11-20 AND MAR=Never married or under 15 years old AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 5  Perc = 0.00%
#            |
# class=False|5
# class=True |0
#            |5
# ERR = 1.000000
# 5
# -----
# Context STATE=VA AND WKHPgroup=0-10 AND AGEPgroup=16-30 AND SEX=Female AND RAC1P=White alone
# Size = 5  Perc = 0.00%
#            |
# class=False|5
# class=True |0
#            |5
# ERR = 1.000000
# 5
# -----
# Context SCHL=Grade 10 AND OCCPgroup=PRS AND AGEPgroup=16-30
# Size = 5  Perc = 0.00%
#            |
# class=False|5
# class=True |0
#            |5
# ERR = 1.000000
# 4
# -----
# Context STATE=UT AND SCHL=Grade 11 AND AGEPgroup=16-30 AND POBPgroup=US
# Size = 4  Perc = 0.00%
#            |
# class=False|4
# class=True |0
#            |4
# ERR = 1.000000
# 4
# -----
# Context STATE=AL AND OCCPgroup=EAT AND RAC1P=Black or African American alone
# Size = 4  Perc = 0.00%
#            |
# class=False|4
# class=True |0
#            |4
# ERR = 1.000000
# 4
# -----
# Context STATE=AL AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Female
# Size = 4  Perc = 0.00%
#            |
# class=False|4
# class=True |0
#            |4
# ERR = 1.000000
# 4
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND SCHL=1 or more years of college credit, no degree AND AGEPgroup=16-30
# Size = 4  Perc = 0.00%
#            |
# class=False|4
# class=True |0
#            |4
# ERR = 1.000000
# 3
# -----
# Context STATE=PR AND OCCPgroup=SAL AND MAR=Never married or under 15 years old AND SEX=Female AND POBPgroup=US
# Size = 3  Perc = 0.00%
#            |
# class=False|3
# class=True |0
#            |3
# ERR = 1.000000
# 3
# -----
# Context STATE=AZ AND WKHPgroup=21-30 AND SCHL=1 or more years of college credit, no degree AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 3  Perc = 0.00%
#            |
# class=False|3
# class=True |0
#            |3
# ERR = 1.000000
# 3
# -----
# Context STATE=AZ AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Male AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone
# Size = 3  Perc = 0.00%
#            |
# class=False|3
# class=True |0
#            |3
# ERR = 1.000000
# 3
# -----
# Context STATE=IA AND OCCPgroup=EAT AND AGEPgroup=16-30 AND MAR=Never married or under 15 years old AND RAC1P=White alone AND POBPgroup=US
# Size = 3  Perc = 0.00%
#            |
# class=False|3
# class=True |0
#            |3
# ERR = 1.000000
# 2
# -----
# Context STATE=AL AND OCCPgroup=EAT AND SCHL=Regular high school diploma AND POBPgroup=US
# Size = 2  Perc = 0.00%
#            |
# class=False|2
# class=True |0
#            |2
# ERR = 1.000000
# 2
# -----
# Context STATE=AZ AND OCCPgroup=EAT AND SCHL=Regular high school diploma AND AGEPgroup=16-30 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 2  Perc = 0.00%
#            |
# class=False|2
# class=True |0
#            |2
# ERR = 1.000000
# 2
# -----
# Context STATE=IA AND WKHPgroup=0-10 AND MAR=Never married or under 15 years old AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions AND RAC1P=White alone AND POBPgroup=US
# Size = 2  Perc = 0.00%
#            |
# class=False|2
# class=True |0
#            |2
# ERR = 1.000000
# 2
# -----
# Context SCHL=Grade 10 AND OCCPgroup=EAT AND WKHPgroup=11-20 AND SEX=Female AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 2  Perc = 0.00%
#            |
# class=False|2
# class=True |0
#            |2
# ERR = 1.000000
# 1
# -----
# Context STATE=OK AND WKHPgroup=21-30 AND AGEPgroup=16-30 AND SEX=Male
# Size = 1  Perc = 0.00%
#            |
# class=False|1
# class=True |0
#            |1
# ERR = 1.000000
# 1
# -----
# Context OCCPgroup=FFF AND STATE=CA AND AGEPgroup=16-30 AND WKHPgroup=31-40 AND COW=Employee of a private for-profit company orbusiness, or of an individual, for wages,salary, or commissions
# Size = 1  Perc = 0.00%
#            |
# class=False|1
# class=True |0
#            |1
# ERR = 1.000000
# 1
# -----
# Context STATE=VA AND WKHPgroup=11-20 AND AGEPgroup=16-30 AND SEX=Male AND RAC1P=White alone
# Size = 1  Perc = 0.00%
#            |
# class=False|1
# class=True |0
#            |1
# ERR = 1.000000
